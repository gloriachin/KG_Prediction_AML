# %% [markdown]
# #### Related to Figure 3
#
# #### Construct XGBoost models to predict the ex vivo drug response using the engineered features from the knowledge graphs

# %%
import pandas as pd
from sklearn import linear_model 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,f1_score
#from sklearn.metrics import auc, confusion_matrix, f1_score, roc_auc_score, accuracy_score, recall_score
import pandas as pd
import numpy as np
from scipy.stats import stats
import os
import matplotlib.pyplot as plt
from random import choices
import xgboost as xgb
import xgboost as XGBClassifier

from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import GridSearchCV, train_test_split

from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import auc, confusion_matrix, f1_score, roc_auc_score, accuracy_score, recall_score

# %%
# Define functions

def Filter_low_Expr(arr):
    total_len = len(arr)
    count = 0
    for i in arr:
        if i > 0:
            count = count + 1
    if count > 0.5*total_len: #If 
        return(True)
    else:
        return(False)
    
def formating_relative_expression(input_data,selected_genes_id, sele_house_keeping_id, KG_reg):
    array_list = []
    new_id_list = []
    for gene1 in selected_genes_id:

        for gene2 in sele_house_keeping_id:
            new_arr = (input_data.loc[[gene1],:].values - input_data.loc[[gene2],:].values)[0]
            new_arr_bi = []
            for i in new_arr:
                if i > 0:
                    new_arr_bi.append(1)
                else:
                    new_arr_bi.append(0)
            array_list.append(new_arr_bi)
            new_id_list.append(dic_gene_map[gene1] + '-' + dic_gene_map[gene2])

    for gene1 in selected_genes_id:
        cur_sele = KG_reg.loc[KG_reg['Target_gene'] == gene1]
        cur_regulators = list(cur_sele.loc[cur_sele['Coef'] < 0]['Regulator'])
        if gene1+"_intercept_" in cur_regulators:
            cur_regulators.remove(gene1+"_intercept_")
        #cur_regulators.remove(gene1+"_RSS")
        cur_regulators_ids = []
        for gene2 in cur_regulators:
            gene2 = dic_gene_map[gene2]
            #cur_regulators_ids.append(dic_gene_map[i])

            new_arr = (input_data.loc[[gene1],:].values - input_data.loc[[gene2],:].values)[0]
            new_arr_bi = []
            for i in new_arr:
                if i > 0:
                    new_arr_bi.append(1)
                else:
                    new_arr_bi.append(0)
            array_list.append(new_arr_bi)
            new_id_list.append(dic_gene_map[gene1] + '-' + dic_gene_map[gene2])

    new_feature_df = pd.DataFrame(array_list)
    new_feature_df.columns = input_data.columns
    new_feature_df.index = new_id_list
    new_feature_df_t = new_feature_df.transpose()
    return(new_feature_df_t)


def train_test_split_gq(df_sele, binary_cutoff, test_size):
    from sklearn.model_selection import train_test_split
    df_neg = df_sele.loc[df_sele['ic50'] > binary_cutoff]
    df_train_1, df_test_1 = train_test_split(df_neg, test_size = test_size)
    df_pos = df_sele.loc[df_sele['ic50'] <= binary_cutoff]
    df_train_2, df_test_2 = train_test_split(df_pos, test_size = test_size)
    
    df_train = pd.concat([df_train_1,df_train_2])
    df_test = pd.concat([df_test_1, df_test_2])
    
    return(df_train, df_test)

def model_run_with_Independent_testSet(train_data,test_data, train_labels, test_labels, independent_labels, independent_features): #modified at 11:46 AM Feb 15
    xgb_model = xgb.XGBClassifier(n_jobs=4)
    clf = GridSearchCV(xgb_model, {'max_depth': [2,3,4],
                                   'n_estimators': [100], 
                                   'learning_rate': [0.05, 0.1],
                                   #'gamma':[1],
                                   #'eta':[0.2,0.3,0.4],
                                  # 'min_child_weight':[1,2],
                                  # 'lambda':[1,2],
                                  # 'subsample':[0.8]
                                  }, verbose=1,cv=5, n_jobs=4) #5-fold cross validation

    clf.fit(train_data, train_labels.values)
    #print(clf.best_score_) #Train data
    para = (clf.best_params_)
    #print(clf.best_params_)

    xgb_model = xgb.XGBClassifier(n_jobs=1, learning_rate = para['learning_rate'], max_depth=para['max_depth'], n_estimators=para['n_estimators'])
    xgb_model.fit(train_data,train_labels.values)
    #predictions = xgb_model.predict(test_data)
    
    predictions = clf.predict(test_data)
    
    predictions_independent = clf.predict(independent_features)
    

    #print(pd.DataFrame({"Meausred": list(test_labels), "Predict": predictions}))

    # Evaluate the accuracy of the XGBoost model in the validation set (beatAML wave 1/2)
    accuracy = accuracy_score(test_labels, predictions)
    cm = confusion_matrix(  list(test_labels), predictions)
    tn = cm[0,0] #labled as negative and predicted as negative 
    fp = cm[0,1] #labeld as negative and predicted as positive
    fn = cm[1,0] #labeld as positive, and predicted as negative
    tp = cm[1,1] #labeld as positive, and predicted as positive
    
    sensitivity = cm[1,1]/(cm[1,0] + cm[1,1]) # TP/(FN + TP)
    specificity = tn/(tn+fp)
    
    precision = cm[1,1]/(cm[0,1] + cm[1,1])
    recall = recall_score(test_labels, predictions)
    blanced_acc = (sensitivity + specificity) /2 
    f1 = f1_score(list(test_labels), predictions)
    
    # Evaluate the accuracy of the XGBoost model in the testing set (beatAML wave 3/4)
    accuracy_independent = accuracy_score(independent_labels, predictions_independent)
    f1_independent = f1_score(independent_labels, predictions_independent)
    cm_independent = confusion_matrix(  list(independent_labels), predictions_independent)
    tn_independent = cm_independent[0,0] #labled as negative and predicted as negative 
    fp_independent = cm_independent[0,1] #labeld as negative and predicted as positive
    fn_independent = cm_independent[1,0] #labeld as positive, and predicted as negative
    tp_independent = cm_independent[1,1] #labeld as positive, and predicted as positive
    
    sensitivity_independent = cm_independent[1,1]/(cm_independent[1,0] + cm_independent[1,1]) # TP/(FN + TP)
    specificity_independent = tn_independent/(tn_independent+fp_independent)
    
    precision_independent = cm_independent[1,1]/(cm_independent[0,1] + cm_independent[1,1])
    recall_independent = recall_score(independent_labels, predictions_independent)
    blanced_acc_independent = (sensitivity_independent + specificity_independent) /2 
    recall_independent = recall_score(independent_labels, predictions_independent)
    # F1 = 2 x [(Precision x Recall) / (Precision + Recall)]

    #print("F1_score: " + str(f1))
    #print("# F1: 2 x [(Precision x Recall) / (Precision + Recall)]")

    result_feature = pd.DataFrame({"Feature":list(test_data.columns), "IMP":xgb_model.feature_importances_})
    result_feature= result_feature.loc[result_feature['IMP']>0].sort_values(by = ['IMP'], ascending = False)

    #features = ((list(result_feature.loc[result_feature['IMP']>0.05].sort_values(by = ["IMP"], ascending = False)['Feature'])))

    result_summary = {}
    result_summary['random_state'] = random_
    result_summary['best_params'] = clf.best_params_
    result_summary['Accuracy'] = accuracy #1
    result_summary['Precision'] = precision #2
    result_summary['sensitivity'] = sensitivity #3
    result_summary['F1_score'] = f1 #4
    result_summary['specificity'] = specificity #5
    result_summary['balanced_acc'] = blanced_acc #6
    result_summary['recall'] = recall #7
    
    
    result_summary['precision_independent'] = precision_independent #1
    result_summary['sensitivity_independent'] = sensitivity_independent #2
    result_summary['specificity_independent'] = specificity_independent #3
    result_summary['blanced_acc_independent'] = blanced_acc_independent #4
    result_summary['ACC_independent'] = accuracy_independent #5
    result_summary['F1_score_independent'] = f1_independent #6
    result_summary['recall_independent'] = recall_independent #7
    
    result_summary['features'] = result_feature
    return(result_summary)

# %%
# Load data
# Gene expression from BeatAML wave 1 and 2
Drug_data = pd.read_csv("../../../Data_resource/Drug_Response.csv",index_col = "Unnamed: 0") 
GE = pd.read_csv("../../../Data_resource/RPKM.csv",index_col = "Unnamed: 0")

#Load features from features that predict drug response, regulatory graph and house keeping genes
#sele_house_keeping =  ["GPS2", "RPS10","ZNF91","FNTA","PSMC1","GPS1","MLH1","ARAF","SF3B2","PSMD2","SRP14","GNB1","HNRNPK","ARF1","RPS11"]
sele_house_keeping = ['RPS10','FNTA','COX6A1','BECN1', 'SF3B2','PSMB2','AUP1','SRP14','HNRNPK', 'CCNI', 'RHOA', 'PABPC1','RPS11','TPT1','FTL']
KG_expr_resp = pd.read_csv("./Data/Supplementary_table_1_KG_Expr_drug_lasso_Coef_features_over0_gt50p.csv")
KG_reg = pd.read_csv("KG_regulatory_graph_Mar1_2023.csv")


# Load testing data from BeatAML wave 3 and 4
BeatAML_wave_3_expr = pd.read_csv("/Users/guangrong/Documents/Datasets/AML/BeatAML-wave1-4/Beat AML collaborator files Waves 1-4/rnaseq/beataml_waves1to4_allnorm.txt", sep = "\t") 
BeatAML_wave_3_drugResponse = pd.read_csv("/Users/guangrong/Documents/Datasets/AML/BeatAML-wave1-4/Beat AML collaborator files Waves 1-4/inhibitor/beataml_probit_curve_fits_v4_distr_nonproprietary.txt", sep = "\t")

# %%
len(set(Drug_data['inhibitor']))
# Out:
# 122

# %%
#Formating gene expression data for testing data
BeatAML_wave_3_expr.index = BeatAML_wave_3_expr['stable_id']
gene_list = (list(BeatAML_wave_3_expr.index))
sample_list = list(set(BeatAML_wave_3_expr.columns) - set(['stable_id','display_label','description','biotype']))
input_data_test = BeatAML_wave_3_expr.loc[list(gene_list), sample_list]

#Formating gene expression data for training data
GE.index = GE['Gene']
gene_list = (list(GE.index))
sample_list = list(set(GE.columns) - set(['Gene','Symbol']))
input_data = GE.loc[list(gene_list), sample_list]

# Define gene_map
gene_map = GE.loc[:,['Gene','Symbol']]
dic_gene_map = {}
for i in range(0,gene_map.shape[0]):
    dic_gene_map[gene_map.iloc[i,0]] = gene_map.iloc[i,1]
    dic_gene_map[gene_map.iloc[i,1]] = gene_map.iloc[i,0]

# %%
# Feature selection: Selection of first neighbors
#Drug = "JQ1"
#Drug = "Trametinib (GSK1120212)"
#Drug = "Selumetinib (AZD6244)"
Drug = "Venetoclax"
#Drug = "Vandetanib (ZD6474)"
#Drug = "Idelalisib"
res1 = KG_expr_resp.loc[KG_expr_resp['Drug'] == Drug]
res1 = res1.sort_values(by = ['coef'])
predictors = list(res1['Gene'])
predictors.remove(Drug+"_RSS")
predictors.remove(Drug+"_intercept")

# Selection of the second neighbors
#res2 = KG_reg.loc[KG_reg['Target_gene'].isin( predictors[0:5] +  predictors[len(predictors)-5:len(predictors)])]
res2 = KG_reg.loc[KG_reg['Target_gene'].isin( predictors)]
res2 = res2.loc[res2['Coef'] <0]

selected_genes = list(KG_expr_resp.loc[KG_expr_resp['Drug'] == Drug]['Symbol'])
selected_genes.remove(Drug+"_RSS")
selected_genes.remove(Drug+"_intercept")
print(len(selected_genes))
# Out:
# 44

# %%
print(selected_genes)
# Out:
# ['CLASP1', 'HDAC5', 'CLIP4', 'NPC2', 'ACOT9', 'UBE2M', 'LILRB2', 'DPF2', 'ECHDC3', 'GDF11', 'MYO7A', 'FGD4', 'PAM', 'VENTX', 'ADPRHL1', 'SPICE1', 'NIPBL', 'SUN1', 'RFNG', 'CD14', 'LILRA3', 'MTSS1', 'BCL2', 'C1QA', 'GOLGA8J', 'LINC00471', 'PLA2G6', 'ZNF502', 'IGF2R', 'ZNF517', 'CASC10', 'RP1-257A7.4', 'AC138623.1', 'CNOT7P1', 'RP11-108L7.4', 'CDK2AP2P2', 'PDXP', 'EEF1GP2', 'CTD-3203P2.1', 'RP11-83N9.5', 'SMC5-AS1', 'ZSCAN16-AS1', 'RP11-355B11.2', 'CASC15']

# %%
# Formating house keeping gene ids
sele_house_keeping_id = []
selected_genes_id = []

for g in selected_genes:
    selected_genes_id.append(dic_gene_map[g])
    
for g in sele_house_keeping:
    if g in dic_gene_map:
        sele_house_keeping_id.append(dic_gene_map[g])

# %%
new_feature_df_t = formating_relative_expression(input_data,selected_genes_id, sele_house_keeping_id, KG_reg)

new_feature_df_test = formating_relative_expression(input_data_test,selected_genes_id, sele_house_keeping_id, KG_reg)

# %%
# Select a subset of features for the modeling   #Relevant to Figure 4F
#new_feature_df_t = new_feature_df_t[['FGD4-MIR4519','NPC2-GATA2']]
#new_feature_df_test = new_feature_df_test[['FGD4-MIR4519','NPC2-GATA2']]

# %%
# Formatting trainning data
Drug_sele_df = Drug_data.loc[Drug_data['inhibitor'] == Drug]
Drug_sele_df.index = Drug_sele_df['lab_id']
Drug_sele_df =Drug_sele_df.loc[:,['ic50']]

df_sele = pd.concat([new_feature_df_t, Drug_sele_df],axis = 1)
df_sele = df_sele.dropna()
df_sele.head(3)
df_sele.shape
# Out:
# (186, 850)

# %%
# Formatting testing data using beatAML wave 3/4

# %%
Drug_sele_df_wave3 = BeatAML_wave_3_drugResponse.loc[BeatAML_wave_3_drugResponse['inhibitor'] == Drug]
Drug_sele_df_wave3.index = Drug_sele_df_wave3['lab_id']
Drug_sele_df_wave3 =Drug_sele_df_wave3.loc[:,['ic50']]

df_sele__wave3 = pd.concat([new_feature_df_test, Drug_sele_df_wave3],axis = 1)
df_sele__wave3 = df_sele__wave3.dropna()
df_sele__wave3.head(3)
df_sele__wave3.shape
# Out:
# (367, 850)

# %%
df_sele__wave3_new = df_sele__wave3.loc[(set(df_sele__wave3.index)-set(df_sele.index)),:]
# Out:
# /var/folders/w1/p1v0w3j165ggfdk4xpn0tzgh0000gp/T/ipykernel_64518/1949196757.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_sele__wave3_new = df_sele__wave3.loc[(set(df_sele__wave3.index)-set(df_sele.index)),:]

# %%
df_sele__wave3_new.shape
# Out:
# (182, 850)

# %%
result_with_threshod = {}
#q10 =np.quantile(Drug_sele_df['ic50'].values, q = 0.25)
q25 =np.quantile(Drug_sele_df['ic50'].values, q = 0.25)
q50 = np.quantile(Drug_sele_df['ic50'].values, q = 0.5)
q75 = np.quantile(Drug_sele_df['ic50'].values, q = 0.75)

threshold_list_label = []
threshold_list = []
if q25 < 10:
    threshold_list.append(q25)
    threshold_list_label.append("Q25:" + str(round(q25,2)) + "μM")
if q50 < 10:
    threshold_list.append(q50)
    threshold_list_label.append("Q50:" + str(round(q50,2)) + "μM")
if q75 < 10:
    threshold_list.append(q75)
    threshold_list_label.append("Q75:" + str(round(q75,2)) + "μM")
#if q75 < 1:
#    threshold_list.append(1)

if max(threshold_list) < 1:
    threshold_list.append(1)
    threshold_list_label.append("1μM")
#if q75 < 1:
    
print(threshold_list)
# Out:
# [0.0190925713799281, 1.45261900330956]

# %%
#Drug = "Venetoclax"

for Threshod in threshold_list:
    print(Threshod)
    data_cur = df_sele # Step 1
    data_cur = data_cur.dropna()
    new_label = []
    for i in data_cur['ic50'].values:
        if i <= Threshod:
            new_label.append(1)
        else:
            new_label.append(0)
    data_cur[Drug+"_bi"] = new_label
    
    df_sele__wave3_cur = df_sele__wave3_new
    new_label = []
    for i in df_sele__wave3_cur['ic50']:
        if i <= Threshod:
            new_label.append(1)
        else:
            new_label.append(0)
    df_sele__wave3_cur[Drug+"_bi"] = new_label

    result_all = {}
    result_all_test_w3 = {}
    for random_ in range(0,200,5): 
        sensitive_data = data_cur.loc[data_cur[Drug+"_bi"] == 1]
        resistant_data = data_cur.loc[data_cur[Drug+"_bi"] == 0]

        train_data_sen, test_data_sen, train_labels_sen, test_labels_sen = train_test_split(sensitive_data.iloc[:,:-2], 
                                                                            sensitive_data.iloc[:,-1],
                                                                            test_size = 0.2, random_state = random_)
        train_data_res, test_data_res, train_labels_res, test_labels_res = train_test_split(resistant_data.iloc[:,:-2], 
                                                                            resistant_data.iloc[:,-1],
                                                                            test_size = 0.2, random_state = random_)

        train_data = pd.concat([train_data_sen, train_data_res])
        test_data = pd.concat([test_data_sen, test_data_res])
        train_labels = pd.concat([train_labels_sen, train_labels_res])
        test_labels = pd.concat([test_labels_sen, test_labels_res])
        
        test_w3_labels = df_sele__wave3_cur[Drug+"_bi"]
        test_w3_features = df_sele__wave3_cur.iloc[:,:-2]
        
        result_all[random_] = model_run_with_Independent_testSet(train_data,test_data, train_labels, test_labels, df_sele__wave3_cur[Drug+"_bi"],  df_sele__wave3_cur.iloc[:,:-2])
        
    result_with_threshod[Threshod] = result_all
# Out:
# 0.0190925713799281
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# 1.45261900330956
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits

# %%
print(df_sele__wave3_cur.shape)
print(train_data.shape)
print(test_data.shape)
# Out:
# (182, 851)
# (148, 849)
# (38, 849)

# %%
result_with_threshod
# Out:
# {0.0190925713799281: {0: {'random_state': 0,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.75,
#    'sensitivity': 0.6666666666666666,
#    'F1_score': 0.7058823529411765,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.7988505747126436,
#    'recall': 0.6666666666666666,
#    'precision_independent': 0.7941176470588235,
#    'sensitivity_independent': 0.42857142857142855,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.6848739495798319,
#    'ACC_independent': 0.7637362637362637,
#    'F1_score_independent': 0.5567010309278351,
#    'recall_independent': 0.42857142857142855,
#    'features':                   Feature       IMP
#    286             CD14-FNTA  0.110178
#    687          ACOT9-MIR621  0.055817
#    777           MTSS1-CEBPA  0.045963
#    137          GDF11-COX6A1  0.045353
#    799     LINC00471-MIR4420  0.043866
#    452         CASC10-COX6A1  0.040994
#    772         LILRA3-MIR940  0.038417
#    674             NPC2-CTCF  0.035550
#    345            C1QA-RPS10  0.034705
#    788          C1QA-MIR4519  0.027914
#    844  RP11-355B11.2-MIR573  0.027797
#    757             RFNG-ATF6  0.027264
#    836   CTD-3203P2.1-MIR553  0.026385
#    645          CASC15-RPS10  0.025918
#    256             SUN1-FNTA  0.023696
#    748             SUN1-JDP2  0.023602
#    421            IGF2R-FNTA  0.022800
#    333            BCL2-BECN1  0.018865
#    808        ZNF502-MIR4453  0.018334
#    316            MTSS1-FNTA  0.017152
#    48             NPC2-BECN1  0.017089
#    809         IGF2R-BHLHE41  0.016449
#    802           PLA2G6-KLF4  0.016338
#    771         LILRA3-MIR621  0.016298
#    315           MTSS1-RPS10  0.016196
#    738            PAM-ZNF680  0.014954
#    834        EEF1GP2-MIR635  0.014946
#    93           LILRB2-BECN1  0.014577
#    732          FGD4-MIR4519  0.014368
#    792         GOLGA8J-PRDM1  0.012675
#    683            ACOT9-NFYB  0.012578
#    804         PLA2G6-POU2F2  0.010715
#    61             ACOT9-FNTA  0.010560
#    837   RP11-83N9.5-MIR644A  0.010559
#    820        CASC10-MIR4420  0.010405
#    707         ECHDC3-MIR940  0.009723
#    741         VENTX-MIR4519  0.008022
#    814         IGF2R-MIR4453  0.007972
#    450          CASC10-RPS10  0.006557
#    828  RP11-108L7.4-MIR644A  0.005900
#    225          SPICE1-RPS10  0.005275
#    287           CD14-COX6A1  0.005202
#    698        LILRB2-MIR4519  0.004977
#    255            SUN1-RPS10  0.004936
#    92          LILRB2-COX6A1  0.004476
#    79            UBE2M-SF3B2  0.003882
#    435          ZNF517-RPS10  0.003373
#    3            CLASP1-BECN1  0.002384
#    420           IGF2R-RPS10  0.002309
#    790         GOLGA8J-KLF12  0.002181
#    285            CD14-RPS10  0.002031
#    791          GOLGA8J-LEF1  0.001527},
#   5: {'random_state': 5,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.9473684210526315,
#    'Precision': 0.8181818181818182,
#    'sensitivity': 1.0,
#    'F1_score': 0.9,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.9655172413793103,
#    'recall': 1.0,
#    'precision_independent': 0.8043478260869565,
#    'sensitivity_independent': 0.5873015873015873,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.7558356676003735,
#    'ACC_independent': 0.8076923076923077,
#    'F1_score_independent': 0.6788990825688073,
#    'recall_independent': 0.5873015873015873,
#    'features':                 Feature       IMP
#    687        ACOT9-MIR621  0.075678
#    286           CD14-FNTA  0.071870
#    452       CASC10-COX6A1  0.067214
#    93         LILRB2-BECN1  0.064981
#    788        C1QA-MIR4519  0.055031
#    ..                  ...       ...
#    791        GOLGA8J-LEF1  0.002213
#    615   ZSCAN16-AS1-RPS10  0.002142
#    823  AC138623.1-MIR4420  0.000758
#    315         MTSS1-RPS10  0.000388
#    816        CASC10-EPAS1  0.000215
#
#    [61 rows x 2 columns]},
#   10: {'random_state': 10,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.75,
#    'sensitivity': 0.6666666666666666,
#    'F1_score': 0.7058823529411765,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.7988505747126436,
#    'recall': 0.6666666666666666,
#    'precision_independent': 0.71875,
#    'sensitivity_independent': 0.36507936507936506,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.6447245564892624,
#    'ACC_independent': 0.7307692307692307,
#    'F1_score_independent': 0.4842105263157895,
#    'recall_independent': 0.36507936507936506,
#    'features':                Feature       IMP
#    764        CD14-ZNF689  0.091949
#    286          CD14-FNTA  0.089827
#    93        LILRB2-BECN1  0.041944
#    687       ACOT9-MIR621  0.041654
#    802        PLA2G6-KLF4  0.036141
#    ..                 ...       ...
#    774     LILRA3-MIR4519  0.001485
#    661       CLASP1-CEBPD  0.001461
#    615  ZSCAN16-AS1-RPS10  0.001369
#    107        DPF2-COX6A1  0.000907
#    790      GOLGA8J-KLF12  0.000261
#
#    [78 rows x 2 columns]},
#   15: {'random_state': 15,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.8947368421052632,
#    'Precision': 0.7777777777777778,
#    'sensitivity': 0.7777777777777778,
#    'F1_score': 0.7777777777777778,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.8544061302681992,
#    'recall': 0.7777777777777778,
#    'precision_independent': 0.78125,
#    'sensitivity_independent': 0.3968253968253968,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.669000933706816,
#    'ACC_independent': 0.7527472527472527,
#    'F1_score_independent': 0.5263157894736843,
#    'recall_independent': 0.3968253968253968,
#    'features':                    Feature       IMP
#    764            CD14-ZNF689  0.129029
#    286              CD14-FNTA  0.073097
#    788           C1QA-MIR4519  0.047739
#    137           GDF11-COX6A1  0.047632
#    848            CASC15-PBX3  0.034122
#    93            LILRB2-BECN1  0.033861
#    687           ACOT9-MIR621  0.033374
#    781             BCL2-NFKB2  0.033039
#    777            MTSS1-CEBPA  0.031146
#    748              SUN1-JDP2  0.030887
#    836    CTD-3203P2.1-MIR553  0.030136
#    674              NPC2-CTCF  0.028204
#    421             IGF2R-FNTA  0.027145
#    802            PLA2G6-KLF4  0.025349
#    824     AC138623.1-MIR5194  0.025051
#    345             C1QA-RPS10  0.022039
#    18             HDAC5-BECN1  0.020507
#    828   RP11-108L7.4-MIR644A  0.019028
#    61              ACOT9-FNTA  0.018856
#    256              SUN1-FNTA  0.018189
#    645           CASC15-RPS10  0.018077
#    799      LINC00471-MIR4420  0.017365
#    846  RP11-355B11.2-MIR4519  0.017166
#    771          LILRA3-MIR621  0.016705
#    818             CASC10-MAF  0.014925
#    808         ZNF502-MIR4453  0.014739
#    778            MTSS1-NR1I2  0.014654
#    814          IGF2R-MIR4453  0.013965
#    820         CASC10-MIR4420  0.013721
#    784              BCL2-TCF4  0.012318
#    91             LILRB2-FNTA  0.011722
#    717             MYO7A-LEF1  0.011484
#    450           CASC10-RPS10  0.011459
#    783               BCL2-SP1  0.011299
#    420            IGF2R-RPS10  0.011139
#    452          CASC10-COX6A1  0.010472
#    225           SPICE1-RPS10  0.009897
#    734              PAM-FOXK1  0.009048
#    451            CASC10-FNTA  0.008598
#    92           LILRB2-COX6A1  0.005471
#    287            CD14-COX6A1  0.004912
#    683             ACOT9-NFYB  0.004231
#    804          PLA2G6-POU2F2  0.003145
#    774         LILRA3-MIR4519  0.002771
#    790          GOLGA8J-KLF12  0.002285},
#   20: {'random_state': 20,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.9210526315789473,
#    'Precision': 0.8,
#    'sensitivity': 0.8888888888888888,
#    'F1_score': 0.8421052631578948,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.9099616858237547,
#    'recall': 0.8888888888888888,
#    'precision_independent': 0.8205128205128205,
#    'sensitivity_independent': 0.5079365079365079,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.7245564892623716,
#    'ACC_independent': 0.7912087912087912,
#    'F1_score_independent': 0.6274509803921569,
#    'recall_independent': 0.5079365079365079,
#    'features':                    Feature       IMP
#    764            CD14-ZNF689  0.097807
#    421             IGF2R-FNTA  0.066983
#    93            LILRB2-BECN1  0.060344
#    748              SUN1-JDP2  0.047913
#    836    CTD-3203P2.1-MIR553  0.042960
#    137           GDF11-COX6A1  0.041308
#    286              CD14-FNTA  0.037285
#    777            MTSS1-CEBPA  0.037196
#    830   RP11-108L7.4-MIR4420  0.036242
#    781             BCL2-NFKB2  0.035301
#    674              NPC2-CTCF  0.028447
#    788           C1QA-MIR4519  0.026035
#    420            IGF2R-RPS10  0.025587
#    687           ACOT9-MIR621  0.025476
#    225           SPICE1-RPS10  0.022546
#    345             C1QA-RPS10  0.022025
#    771          LILRA3-MIR621  0.021946
#    452          CASC10-COX6A1  0.021013
#    726          MYO7A-MIR378I  0.019105
#    672           CLIP4-MIR635  0.018022
#    181               PAM-FNTA  0.016721
#    61              ACOT9-FNTA  0.016295
#    799      LINC00471-MIR4420  0.016221
#    783               BCL2-SP1  0.015059
#    824     AC138623.1-MIR5194  0.014972
#    828   RP11-108L7.4-MIR644A  0.014191
#    422           IGF2R-COX6A1  0.013795
#    645           CASC15-RPS10  0.012638
#    802            PLA2G6-KLF4  0.012273
#    789           GOLGA8J-CREM  0.012136
#    734              PAM-FOXK1  0.011702
#    30             CLIP4-RPS10  0.010088
#    287            CD14-COX6A1  0.009997
#    136             GDF11-FNTA  0.009164
#    846  RP11-355B11.2-MIR4519  0.009159
#    333             BCL2-BECN1  0.009008
#    717             MYO7A-LEF1  0.008385
#    820         CASC10-MIR4420  0.007933
#    256              SUN1-FNTA  0.007858
#    92           LILRB2-COX6A1  0.007743
#    289             CD14-SF3B2  0.007731
#    809          IGF2R-BHLHE41  0.007569
#    804          PLA2G6-POU2F2  0.004447
#    841    ZSCAN16-AS1-MIR4312  0.003583
#    288             CD14-BECN1  0.003476
#    784              BCL2-TCF4  0.002884
#    844   RP11-355B11.2-MIR573  0.000693
#    774         LILRA3-MIR4519  0.000678
#    180              PAM-RPS10  0.000057},
#   25: {'random_state': 25,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.7631578947368421,
#    'Precision': 0.5,
#    'sensitivity': 0.4444444444444444,
#    'F1_score': 0.47058823529411764,
#    'specificity': 0.8620689655172413,
#    'balanced_acc': 0.6532567049808429,
#    'recall': 0.4444444444444444,
#    'precision_independent': 0.7608695652173914,
#    'sensitivity_independent': 0.5555555555555556,
#    'specificity_independent': 0.907563025210084,
#    'blanced_acc_independent': 0.7315592903828199,
#    'ACC_independent': 0.7857142857142857,
#    'F1_score_independent': 0.6422018348623854,
#    'recall_independent': 0.5555555555555556,
#    'features':                    Feature       IMP
#    286              CD14-FNTA  0.162546
#    135            GDF11-RPS10  0.064410
#    781             BCL2-NFKB2  0.048334
#    687           ACOT9-MIR621  0.043246
#    392          PLA2G6-COX6A1  0.043106
#    848            CASC15-PBX3  0.040578
#    421             IGF2R-FNTA  0.037158
#    667           HDAC5-ZBTB7A  0.036875
#    836    CTD-3203P2.1-MIR553  0.031981
#    777            MTSS1-CEBPA  0.031869
#    225           SPICE1-RPS10  0.028100
#    333             BCL2-BECN1  0.027189
#    256              SUN1-FNTA  0.023645
#    288             CD14-BECN1  0.023311
#    674              NPC2-CTCF  0.022497
#    788           C1QA-MIR4519  0.019336
#    767         LILRA3-MIR4442  0.019008
#    137           GDF11-COX6A1  0.017368
#    451            CASC10-FNTA  0.015173
#    771          LILRA3-MIR621  0.015163
#    707          ECHDC3-MIR940  0.014080
#    138            GDF11-BECN1  0.013916
#    846  RP11-355B11.2-MIR4519  0.013602
#    683             ACOT9-NFYB  0.013592
#    450           CASC10-RPS10  0.013496
#    822        AC138623.1-LEF1  0.013129
#    332            BCL2-COX6A1  0.012930
#    828   RP11-108L7.4-MIR644A  0.012809
#    772          LILRA3-MIR940  0.012225
#    91             LILRB2-FNTA  0.012009
#    735              PAM-HOXB3  0.010913
#    823     AC138623.1-MIR4420  0.008723
#    799      LINC00471-MIR4420  0.008420
#    774         LILRA3-MIR4519  0.008379
#    136             GDF11-FNTA  0.007839
#    61              ACOT9-FNTA  0.007648
#    422           IGF2R-COX6A1  0.007622
#    18             HDAC5-BECN1  0.007564
#    345             C1QA-RPS10  0.007278
#    832      CDK2AP2P2-MIR4292  0.006873
#    180              PAM-RPS10  0.005882
#    776           MTSS1-BCL11A  0.005152
#    820         CASC10-MIR4420  0.005041
#    738             PAM-ZNF680  0.004883
#    796      LINC00471-MIR644A  0.004812
#    420            IGF2R-RPS10  0.004397
#    834         EEF1GP2-MIR635  0.003735
#    243            NIPBL-BECN1  0.001706
#    748              SUN1-JDP2  0.000239
#    694          UBE2M-MIR3916  0.000214},
#   30: {'random_state': 30,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.9210526315789473,
#    'Precision': 0.8,
#    'sensitivity': 0.8888888888888888,
#    'F1_score': 0.8421052631578948,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.9099616858237547,
#    'recall': 0.8888888888888888,
#    'precision_independent': 0.7804878048780488,
#    'sensitivity_independent': 0.5079365079365079,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.7161531279178338,
#    'ACC_independent': 0.7802197802197802,
#    'F1_score_independent': 0.6153846153846154,
#    'recall_independent': 0.5079365079365079,
#    'features':            Feature       IMP
#    764    CD14-ZNF689  0.161947
#    452  CASC10-COX6A1  0.068097
#    286      CD14-FNTA  0.063111
#    93    LILRB2-BECN1  0.049359
#    137   GDF11-COX6A1  0.043509
#    ..             ...       ...
#    285     CD14-RPS10  0.001295
#    300   LILRA3-RPS10  0.000958
#    810     IGF2R-CUX1  0.000758
#    138    GDF11-BECN1  0.000531
#    181       PAM-FNTA  0.000130
#
#    [71 rows x 2 columns]},
#   35: {'random_state': 35,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.8947368421052632,
#    'Precision': 0.7777777777777778,
#    'sensitivity': 0.7777777777777778,
#    'F1_score': 0.7777777777777778,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.8544061302681992,
#    'recall': 0.7777777777777778,
#    'precision_independent': 0.7727272727272727,
#    'sensitivity_independent': 0.5396825396825397,
#    'specificity_independent': 0.9159663865546218,
#    'blanced_acc_independent': 0.7278244631185807,
#    'ACC_independent': 0.7857142857142857,
#    'F1_score_independent': 0.6355140186915886,
#    'recall_independent': 0.5396825396825397,
#    'features':                   Feature       IMP
#    286             CD14-FNTA  0.100742
#    452         CASC10-COX6A1  0.083712
#    137          GDF11-COX6A1  0.075486
#    751            SUN1-NR2C2  0.050149
#    748             SUN1-JDP2  0.046093
#    ..                    ...       ...
#    829  RP11-108L7.4-MIR3128  0.001137
#    93           LILRB2-BECN1  0.001122
#    763              CD14-WT1  0.001062
#    788          C1QA-MIR4519  0.000298
#    820        CASC10-MIR4420  0.000196
#
#    [73 rows x 2 columns]},
#   40: {'random_state': 40,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.8421052631578947,
#    'Precision': 0.7142857142857143,
#    'sensitivity': 0.5555555555555556,
#    'F1_score': 0.6250000000000001,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.7432950191570882,
#    'recall': 0.5555555555555556,
#    'precision_independent': 0.7631578947368421,
#    'sensitivity_independent': 0.4603174603174603,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.69234360410831,
#    'ACC_independent': 0.7637362637362637,
#    'F1_score_independent': 0.5742574257425742,
#    'recall_independent': 0.4603174603174603,
#    'features':                    Feature       IMP
#    286              CD14-FNTA  0.115058
#    777            MTSS1-CEBPA  0.068823
#    137           GDF11-COX6A1  0.051811
#    345             C1QA-RPS10  0.041339
#    674              NPC2-CTCF  0.040672
#    757              RFNG-ATF6  0.035960
#    93            LILRB2-BECN1  0.032621
#    748              SUN1-JDP2  0.029292
#    421             IGF2R-FNTA  0.027566
#    765           CD14-MIR4519  0.025425
#    135            GDF11-RPS10  0.024202
#    332            BCL2-COX6A1  0.024007
#    788           C1QA-MIR4519  0.022995
#    645           CASC15-RPS10  0.022843
#    683             ACOT9-NFYB  0.022632
#    91             LILRB2-FNTA  0.022242
#    333             BCL2-BECN1  0.021651
#    829   RP11-108L7.4-MIR3128  0.021431
#    836    CTD-3203P2.1-MIR553  0.020149
#    844   RP11-355B11.2-MIR573  0.018104
#    808         ZNF502-MIR4453  0.017739
#    809          IGF2R-BHLHE41  0.017588
#    256              SUN1-FNTA  0.015382
#    392          PLA2G6-COX6A1  0.015316
#    90            LILRB2-RPS10  0.015108
#    420            IGF2R-RPS10  0.014767
#    771          LILRA3-MIR621  0.014658
#    792          GOLGA8J-PRDM1  0.014260
#    726          MYO7A-MIR378I  0.012628
#    767         LILRA3-MIR4442  0.012154
#    18             HDAC5-BECN1  0.011899
#    778            MTSS1-NR1I2  0.011689
#    61              ACOT9-FNTA  0.010938
#    772          LILRA3-MIR940  0.010706
#    834         EEF1GP2-MIR635  0.009679
#    846  RP11-355B11.2-MIR4519  0.009502
#    824     AC138623.1-MIR5194  0.009470
#    847            CASC15-KLF4  0.008026
#    451            CASC10-FNTA  0.007891
#    816           CASC10-EPAS1  0.007728
#    706         ECHDC3-MIR3609  0.007284
#    842    ZSCAN16-AS1-MIR3176  0.007231
#    799      LINC00471-MIR4420  0.006649
#    315            MTSS1-RPS10  0.006593
#    707          ECHDC3-MIR940  0.006322
#    839       SMC5-AS1-MIR378I  0.005137
#    805          PLA2G6-ZBTB7A  0.004669
#    826        CNOT7P1-MIR4420  0.004263
#    435           ZNF517-RPS10  0.003894
#    138            GDF11-BECN1  0.002722
#    823     AC138623.1-MIR4420  0.002030
#    107            DPF2-COX6A1  0.001779
#    495          CNOT7P1-RPS10  0.001591
#    791           GOLGA8J-LEF1  0.001343
#    288             CD14-BECN1  0.001133
#    800           PLA2G6-CEBPA  0.001006
#    108             DPF2-BECN1  0.000403},
#   45: {'random_state': 45,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.8421052631578947,
#    'Precision': 0.6153846153846154,
#    'sensitivity': 0.8888888888888888,
#    'F1_score': 0.7272727272727274,
#    'specificity': 0.8275862068965517,
#    'balanced_acc': 0.8582375478927202,
#    'recall': 0.8888888888888888,
#    'precision_independent': 0.6935483870967742,
#    'sensitivity_independent': 0.6825396825396826,
#    'specificity_independent': 0.8403361344537815,
#    'blanced_acc_independent': 0.761437908496732,
#    'ACC_independent': 0.7857142857142857,
#    'F1_score_independent': 0.6880000000000001,
#    'recall_independent': 0.6825396825396826,
#    'features':             Feature       IMP
#    286       CD14-FNTA  0.127209
#    687    ACOT9-MIR621  0.075850
#    452   CASC10-COX6A1  0.072845
#    772   LILRA3-MIR940  0.044317
#    345      C1QA-RPS10  0.042386
#    ..              ...       ...
#    285      CD14-RPS10  0.000638
#    765    CD14-MIR4519  0.000354
#    820  CASC10-MIR4420  0.000320
#    804   PLA2G6-POU2F2  0.000098
#    287     CD14-COX6A1  0.000048
#
#    [62 rows x 2 columns]},
#   50: {'random_state': 50,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.7894736842105263,
#    'Precision': 0.6,
#    'sensitivity': 0.3333333333333333,
#    'F1_score': 0.42857142857142855,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.632183908045977,
#    'recall': 0.3333333333333333,
#    'precision_independent': 0.8205128205128205,
#    'sensitivity_independent': 0.5079365079365079,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.7245564892623716,
#    'ACC_independent': 0.7912087912087912,
#    'F1_score_independent': 0.6274509803921569,
#    'recall_independent': 0.5079365079365079,
#    'features':                    Feature       IMP
#    286              CD14-FNTA  0.164295
#    48              NPC2-BECN1  0.065581
#    421             IGF2R-FNTA  0.043616
#    788           C1QA-MIR4519  0.041645
#    452          CASC10-COX6A1  0.037968
#    ..                     ...       ...
#    846  RP11-355B11.2-MIR4519  0.001977
#    796      LINC00471-MIR644A  0.001810
#    802            PLA2G6-KLF4  0.001608
#    272            RFNG-COX6A1  0.001344
#    763               CD14-WT1  0.001259
#
#    [61 rows x 2 columns]},
#   55: {'random_state': 55,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.9473684210526315,
#    'Precision': 0.8888888888888888,
#    'sensitivity': 0.8888888888888888,
#    'F1_score': 0.8888888888888888,
#    'specificity': 0.9655172413793104,
#    'balanced_acc': 0.9272030651340997,
#    'recall': 0.8888888888888888,
#    'precision_independent': 0.7692307692307693,
#    'sensitivity_independent': 0.47619047619047616,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.7002801120448179,
#    'ACC_independent': 0.7692307692307693,
#    'F1_score_independent': 0.588235294117647,
#    'recall_independent': 0.47619047619047616,
#    'features':                   Feature       IMP
#    687          ACOT9-MIR621  0.069498
#    763              CD14-WT1  0.064099
#    286             CD14-FNTA  0.056427
#    828  RP11-108L7.4-MIR644A  0.052543
#    796     LINC00471-MIR644A  0.046438
#    ..                    ...       ...
#    256             SUN1-FNTA  0.001769
#    495         CNOT7P1-RPS10  0.001725
#    18            HDAC5-BECN1  0.001680
#    802           PLA2G6-KLF4  0.001177
#    732          FGD4-MIR4519  0.000861
#
#    [72 rows x 2 columns]},
#   60: {'random_state': 60,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.75,
#    'sensitivity': 0.6666666666666666,
#    'F1_score': 0.7058823529411765,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.7988505747126436,
#    'recall': 0.6666666666666666,
#    'precision_independent': 0.8055555555555556,
#    'sensitivity_independent': 0.4603174603174603,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.7007469654528478,
#    'ACC_independent': 0.7747252747252747,
#    'F1_score_independent': 0.5858585858585859,
#    'recall_independent': 0.4603174603174603,
#    'features':                   Feature       IMP
#    286             CD14-FNTA  0.152233
#    452         CASC10-COX6A1  0.083232
#    734             PAM-FOXK1  0.039805
#    748             SUN1-JDP2  0.037930
#    137          GDF11-COX6A1  0.032041
#    ..                    ...       ...
#    803          PLA2G6-NR2F6  0.000924
#    781            BCL2-NFKB2  0.000614
#    829  RP11-108L7.4-MIR3128  0.000448
#    805         PLA2G6-ZBTB7A  0.000310
#    823    AC138623.1-MIR4420  0.000013
#
#    [65 rows x 2 columns]},
#   65: {'random_state': 65,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.9210526315789473,
#    'Precision': 0.75,
#    'sensitivity': 1.0,
#    'F1_score': 0.8571428571428571,
#    'specificity': 0.896551724137931,
#    'balanced_acc': 0.9482758620689655,
#    'recall': 1.0,
#    'precision_independent': 0.6875,
#    'sensitivity_independent': 0.5238095238095238,
#    'specificity_independent': 0.8739495798319328,
#    'blanced_acc_independent': 0.6988795518207283,
#    'ACC_independent': 0.7527472527472527,
#    'F1_score_independent': 0.5945945945945946,
#    'recall_independent': 0.5238095238095238,
#    'features':                   Feature       IMP
#    687          ACOT9-MIR621  0.090318
#    764           CD14-ZNF689  0.084520
#    286             CD14-FNTA  0.061846
#    848           CASC15-PBX3  0.043316
#    814         IGF2R-MIR4453  0.036931
#    ..                    ...       ...
#    136            GDF11-FNTA  0.001687
#    804         PLA2G6-POU2F2  0.001655
#    287           CD14-COX6A1  0.001626
#    830  RP11-108L7.4-MIR4420  0.001618
#    288            CD14-BECN1  0.000181
#
#    [69 rows x 2 columns]},
#   70: {'random_state': 70,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.8333333333333334,
#    'sensitivity': 0.5555555555555556,
#    'F1_score': 0.6666666666666667,
#    'specificity': 0.9655172413793104,
#    'balanced_acc': 0.7605363984674329,
#    'recall': 0.5555555555555556,
#    'precision_independent': 0.673469387755102,
#    'sensitivity_independent': 0.5238095238095238,
#    'specificity_independent': 0.865546218487395,
#    'blanced_acc_independent': 0.6946778711484594,
#    'ACC_independent': 0.7472527472527473,
#    'F1_score_independent': 0.5892857142857143,
#    'recall_independent': 0.5238095238095238,
#    'features':            Feature       IMP
#    286      CD14-FNTA  0.134338
#    687   ACOT9-MIR621  0.082456
#    764    CD14-ZNF689  0.056968
#    748      SUN1-JDP2  0.047075
#    345     C1QA-RPS10  0.043289
#    ..             ...       ...
#    790  GOLGA8J-KLF12  0.001659
#    300   LILRA3-RPS10  0.001060
#    802    PLA2G6-KLF4  0.000888
#    287    CD14-COX6A1  0.000709
#    450   CASC10-RPS10  0.000192
#
#    [68 rows x 2 columns]},
#   75: {'random_state': 75,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.8421052631578947,
#    'Precision': 0.6666666666666666,
#    'sensitivity': 0.6666666666666666,
#    'F1_score': 0.6666666666666666,
#    'specificity': 0.896551724137931,
#    'balanced_acc': 0.7816091954022988,
#    'recall': 0.6666666666666666,
#    'precision_independent': 0.7368421052631579,
#    'sensitivity_independent': 0.4444444444444444,
#    'specificity_independent': 0.9159663865546218,
#    'blanced_acc_independent': 0.6802054154995332,
#    'ACC_independent': 0.7527472527472527,
#    'F1_score_independent': 0.5544554455445545,
#    'recall_independent': 0.4444444444444444,
#    'features':                    Feature       IMP
#    93            LILRB2-BECN1  0.089020
#    764            CD14-ZNF689  0.082312
#    286              CD14-FNTA  0.076762
#    687           ACOT9-MIR621  0.072284
#    765           CD14-MIR4519  0.046548
#    829   RP11-108L7.4-MIR3128  0.043351
#    830   RP11-108L7.4-MIR4420  0.042707
#    345             C1QA-RPS10  0.040063
#    137           GDF11-COX6A1  0.032585
#    138            GDF11-BECN1  0.024017
#    61              ACOT9-FNTA  0.023878
#    674              NPC2-CTCF  0.022726
#    778            MTSS1-NR1I2  0.020916
#    422           IGF2R-COX6A1  0.020713
#    421             IGF2R-FNTA  0.020634
#    301            LILRA3-FNTA  0.020273
#    255             SUN1-RPS10  0.019557
#    836    CTD-3203P2.1-MIR553  0.016176
#    225           SPICE1-RPS10  0.016149
#    256              SUN1-FNTA  0.015129
#    792          GOLGA8J-PRDM1  0.014864
#    748              SUN1-JDP2  0.012000
#    333             BCL2-BECN1  0.011363
#    846  RP11-355B11.2-MIR4519  0.011074
#    757              RFNG-ATF6  0.010826
#    788           C1QA-MIR4519  0.010432
#    837    RP11-83N9.5-MIR644A  0.010356
#    767         LILRA3-MIR4442  0.010152
#    288             CD14-BECN1  0.010131
#    91             LILRB2-FNTA  0.009962
#    770         LILRA3-MIR3153  0.009595
#    392          PLA2G6-COX6A1  0.009233
#    772          LILRA3-MIR940  0.009219
#    181               PAM-FNTA  0.009102
#    332            BCL2-COX6A1  0.008009
#    779          MTSS1-MIR3936  0.007094
#    717             MYO7A-LEF1  0.007086
#    819          CASC10-POU6F1  0.006480
#    711            GDF11-TRPS1  0.006099
#    79             UBE2M-SF3B2  0.005974
#    450           CASC10-RPS10  0.005922
#    667           HDAC5-ZBTB7A  0.005215
#    777            MTSS1-CEBPA  0.005076
#    287            CD14-COX6A1  0.004866
#    92           LILRB2-COX6A1  0.004537
#    822        AC138623.1-LEF1  0.004510
#    735              PAM-HOXB3  0.004448
#    771          LILRA3-MIR621  0.003758
#    272            RFNG-COX6A1  0.003754
#    726          MYO7A-MIR378I  0.003685
#    820         CASC10-MIR4420  0.003391
#    832      CDK2AP2P2-MIR4292  0.003256
#    683             ACOT9-NFYB  0.002953
#    804          PLA2G6-POU2F2  0.002394
#    195            VENTX-RPS10  0.002341
#    18             HDAC5-BECN1  0.001463
#    707          ECHDC3-MIR940  0.001275
#    661           CLASP1-CEBPD  0.001182
#    615      ZSCAN16-AS1-RPS10  0.001124},
#   80: {'random_state': 80,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.8157894736842105,
#    'Precision': 0.6666666666666666,
#    'sensitivity': 0.4444444444444444,
#    'F1_score': 0.5333333333333333,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.6877394636015326,
#    'recall': 0.4444444444444444,
#    'precision_independent': 0.7380952380952381,
#    'sensitivity_independent': 0.49206349206349204,
#    'specificity_independent': 0.907563025210084,
#    'blanced_acc_independent': 0.699813258636788,
#    'ACC_independent': 0.7637362637362637,
#    'F1_score_independent': 0.5904761904761904,
#    'recall_independent': 0.49206349206349204,
#    'features':             Feature       IMP
#    286       CD14-FNTA  0.170516
#    92    LILRB2-COX6A1  0.078510
#    687    ACOT9-MIR621  0.054576
#    421      IGF2R-FNTA  0.044387
#    93     LILRB2-BECN1  0.040135
#    ..              ...       ...
#    255      SUN1-RPS10  0.000955
#    288      CD14-BECN1  0.000851
#    451     CASC10-FNTA  0.000512
#    770  LILRA3-MIR3153  0.000243
#    690     UBE2M-MEF2A  0.000087
#
#    [70 rows x 2 columns]},
#   85: {'random_state': 85,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.8421052631578947,
#    'Precision': 0.8,
#    'sensitivity': 0.4444444444444444,
#    'F1_score': 0.5714285714285714,
#    'specificity': 0.9655172413793104,
#    'balanced_acc': 0.7049808429118773,
#    'recall': 0.4444444444444444,
#    'precision_independent': 0.7083333333333334,
#    'sensitivity_independent': 0.5396825396825397,
#    'specificity_independent': 0.8823529411764706,
#    'blanced_acc_independent': 0.711017740429505,
#    'ACC_independent': 0.7637362637362637,
#    'F1_score_independent': 0.6126126126126126,
#    'recall_independent': 0.5396825396825397,
#    'features':             Feature           IMP
#    286       CD14-FNTA  1.017829e-01
#    748       SUN1-JDP2  5.377551e-02
#    687    ACOT9-MIR621  4.759199e-02
#    773   LILRA3-MIR643  4.544438e-02
#    48       NPC2-BECN1  4.441030e-02
#    ..              ...           ...
#    107     DPF2-COX6A1  9.255339e-04
#    802     PLA2G6-KLF4  7.217263e-04
#    774  LILRA3-MIR4519  3.886853e-04
#    661    CLASP1-CEBPD  3.715190e-04
#    816    CASC10-EPAS1  7.102479e-08
#
#    [68 rows x 2 columns]},
#   90: {'random_state': 90,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.8947368421052632,
#    'Precision': 1.0,
#    'sensitivity': 0.5555555555555556,
#    'F1_score': 0.7142857142857143,
#    'specificity': 1.0,
#    'balanced_acc': 0.7777777777777778,
#    'recall': 0.5555555555555556,
#    'precision_independent': 0.71875,
#    'sensitivity_independent': 0.36507936507936506,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.6447245564892624,
#    'ACC_independent': 0.7307692307692307,
#    'F1_score_independent': 0.4842105263157895,
#    'recall_independent': 0.36507936507936506,
#    'features':                    Feature       IMP
#    286              CD14-FNTA  0.071975
#    452          CASC10-COX6A1  0.068092
#    687           ACOT9-MIR621  0.052240
#    748              SUN1-JDP2  0.046123
#    137           GDF11-COX6A1  0.045144
#    788           C1QA-MIR4519  0.044422
#    777            MTSS1-CEBPA  0.037206
#    93            LILRB2-BECN1  0.037129
#    420            IGF2R-RPS10  0.035747
#    779          MTSS1-MIR3936  0.029292
#    765           CD14-MIR4519  0.027745
#    674              NPC2-CTCF  0.026527
#    345             C1QA-RPS10  0.023865
#    256              SUN1-FNTA  0.022384
#    848            CASC15-PBX3  0.021793
#    841    ZSCAN16-AS1-MIR4312  0.021440
#    838    RP11-83N9.5-MIR4420  0.020100
#    138            GDF11-BECN1  0.019981
#    91             LILRB2-FNTA  0.018957
#    757              RFNG-ATF6  0.017027
#    421             IGF2R-FNTA  0.014353
#    771          LILRA3-MIR621  0.014297
#    818             CASC10-MAF  0.013647
#    784              BCL2-TCF4  0.013640
#    789           GOLGA8J-CREM  0.013381
#    836    CTD-3203P2.1-MIR553  0.013219
#    672           CLIP4-MIR635  0.012275
#    450           CASC10-RPS10  0.011052
#    846  RP11-355B11.2-MIR4519  0.011013
#    837    RP11-83N9.5-MIR644A  0.010930
#    61              ACOT9-FNTA  0.010661
#    809          IGF2R-BHLHE41  0.009765
#    767         LILRA3-MIR4442  0.009420
#    772          LILRA3-MIR940  0.008813
#    18             HDAC5-BECN1  0.008536
#    799      LINC00471-MIR4420  0.008312
#    333             BCL2-BECN1  0.008176
#    707          ECHDC3-MIR940  0.007811
#    792          GOLGA8J-PRDM1  0.007682
#    79             UBE2M-SF3B2  0.007614
#    717             MYO7A-LEF1  0.007518
#    663          CLASP1-POU2F2  0.007265
#    285             CD14-RPS10  0.006904
#    844   RP11-355B11.2-MIR573  0.006625
#    136             GDF11-FNTA  0.006613
#    92           LILRB2-COX6A1  0.006124
#    225           SPICE1-RPS10  0.005751
#    768         LILRA3-MIR3936  0.005683
#    808         ZNF502-MIR4453  0.005628
#    802            PLA2G6-KLF4  0.005386
#    726          MYO7A-MIR378I  0.005368
#    774         LILRA3-MIR4519  0.005325
#    763               CD14-WT1  0.004847
#    711            GDF11-TRPS1  0.004828
#    734              PAM-FOXK1  0.004353
#    683             ACOT9-NFYB  0.003448
#    287            CD14-COX6A1  0.002990
#    392          PLA2G6-COX6A1  0.001871
#    823     AC138623.1-MIR4420  0.000970
#    288             CD14-BECN1  0.000718},
#   95: {'random_state': 95,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.9210526315789473,
#    'Precision': 0.875,
#    'sensitivity': 0.7777777777777778,
#    'F1_score': 0.823529411764706,
#    'specificity': 0.9655172413793104,
#    'balanced_acc': 0.8716475095785441,
#    'recall': 0.7777777777777778,
#    'precision_independent': 0.7878787878787878,
#    'sensitivity_independent': 0.4126984126984127,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.676937441643324,
#    'ACC_independent': 0.7582417582417582,
#    'F1_score_independent': 0.5416666666666666,
#    'recall_independent': 0.4126984126984127,
#    'features':                   Feature       IMP
#    345            C1QA-RPS10  0.076811
#    788          C1QA-MIR4519  0.068707
#    421            IGF2R-FNTA  0.059025
#    757             RFNG-ATF6  0.052351
#    687          ACOT9-MIR621  0.046456
#    ..                    ...       ...
#    315           MTSS1-RPS10  0.001694
#    829  RP11-108L7.4-MIR3128  0.001609
#    774        LILRA3-MIR4519  0.001265
#    256             SUN1-FNTA  0.000468
#    694         UBE2M-MIR3916  0.000302
#
#    [61 rows x 2 columns]},
#   100: {'random_state': 100,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.8421052631578947,
#    'Precision': 1.0,
#    'sensitivity': 0.3333333333333333,
#    'F1_score': 0.5,
#    'specificity': 1.0,
#    'balanced_acc': 0.6666666666666666,
#    'recall': 0.3333333333333333,
#    'precision_independent': 0.7352941176470589,
#    'sensitivity_independent': 0.3968253968253968,
#    'specificity_independent': 0.9243697478991597,
#    'blanced_acc_independent': 0.6605975723622782,
#    'ACC_independent': 0.7417582417582418,
#    'F1_score_independent': 0.5154639175257733,
#    'recall_independent': 0.3968253968253968,
#    'features':                  Feature       IMP
#    764          CD14-ZNF689  0.121078
#    286            CD14-FNTA  0.103856
#    421           IGF2R-FNTA  0.058429
#    345           C1QA-RPS10  0.043855
#    137         GDF11-COX6A1  0.042297
#    748            SUN1-JDP2  0.041410
#    452        CASC10-COX6A1  0.040750
#    687         ACOT9-MIR621  0.032375
#    422         IGF2R-COX6A1  0.030221
#    287          CD14-COX6A1  0.028545
#    225         SPICE1-RPS10  0.028066
#    135          GDF11-RPS10  0.027242
#    824   AC138623.1-MIR5194  0.025089
#    645         CASC15-RPS10  0.024413
#    301          LILRA3-FNTA  0.022854
#    138          GDF11-BECN1  0.021580
#    674            NPC2-CTCF  0.021487
#    61            ACOT9-FNTA  0.019365
#    836  CTD-3203P2.1-MIR553  0.019138
#    672         CLIP4-MIR635  0.018069
#    780           BCL2-FOXO1  0.017056
#    726        MYO7A-MIR378I  0.015062
#    805        PLA2G6-ZBTB7A  0.014720
#    18           HDAC5-BECN1  0.014279
#    30           CLIP4-RPS10  0.014014
#    777          MTSS1-CEBPA  0.012977
#    706       ECHDC3-MIR3609  0.012669
#    256            SUN1-FNTA  0.012614
#    767       LILRA3-MIR4442  0.012417
#    818           CASC10-MAF  0.011647
#    707        ECHDC3-MIR940  0.011345
#    837  RP11-83N9.5-MIR644A  0.011344
#    717           MYO7A-LEF1  0.011241
#    333           BCL2-BECN1  0.010447
#    799    LINC00471-MIR4420  0.010170
#    771        LILRA3-MIR621  0.010007
#    300         LILRA3-RPS10  0.008715
#    92         LILRB2-COX6A1  0.005661
#    769       LILRA3-MIR3609  0.004351
#    804        PLA2G6-POU2F2  0.004137
#    774       LILRA3-MIR4519  0.003169
#    791         GOLGA8J-LEF1  0.001029
#    288           CD14-BECN1  0.000812},
#   105: {'random_state': 105,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.9210526315789473,
#    'Precision': 0.75,
#    'sensitivity': 1.0,
#    'F1_score': 0.8571428571428571,
#    'specificity': 0.896551724137931,
#    'balanced_acc': 0.9482758620689655,
#    'recall': 1.0,
#    'precision_independent': 0.7391304347826086,
#    'sensitivity_independent': 0.5396825396825397,
#    'specificity_independent': 0.8991596638655462,
#    'blanced_acc_independent': 0.719421101774043,
#    'ACC_independent': 0.7747252747252747,
#    'F1_score_independent': 0.6238532110091742,
#    'recall_independent': 0.5396825396825397,
#    'features':                  Feature       IMP
#    286            CD14-FNTA  0.076955
#    687         ACOT9-MIR621  0.061268
#    748            SUN1-JDP2  0.057847
#    674            NPC2-CTCF  0.044980
#    301          LILRA3-FNTA  0.037868
#    ..                   ...       ...
#    763             CD14-WT1  0.002061
#    226          SPICE1-FNTA  0.001648
#    288           CD14-BECN1  0.000730
#    48            NPC2-BECN1  0.000606
#    837  RP11-83N9.5-MIR644A  0.000595
#
#    [73 rows x 2 columns]},
#   110: {'random_state': 110,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.75,
#    'sensitivity': 0.6666666666666666,
#    'F1_score': 0.7058823529411765,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.7988505747126436,
#    'recall': 0.6666666666666666,
#    'precision_independent': 0.7291666666666666,
#    'sensitivity_independent': 0.5555555555555556,
#    'specificity_independent': 0.8907563025210085,
#    'blanced_acc_independent': 0.7231559290382821,
#    'ACC_independent': 0.7747252747252747,
#    'F1_score_independent': 0.6306306306306306,
#    'recall_independent': 0.5555555555555556,
#    'features':                   Feature       IMP
#    286             CD14-FNTA  0.131408
#    764           CD14-ZNF689  0.127214
#    93           LILRB2-BECN1  0.062061
#    711           GDF11-TRPS1  0.046886
#    687          ACOT9-MIR621  0.040909
#    674             NPC2-CTCF  0.039529
#    777           MTSS1-CEBPA  0.034820
#    137          GDF11-COX6A1  0.031763
#    836   CTD-3203P2.1-MIR553  0.027241
#    345            C1QA-RPS10  0.027168
#    848           CASC15-PBX3  0.027149
#    392         PLA2G6-COX6A1  0.025024
#    60            ACOT9-RPS10  0.024299
#    774        LILRA3-MIR4519  0.022084
#    672          CLIP4-MIR635  0.020459
#    421            IGF2R-FNTA  0.017932
#    91            LILRB2-FNTA  0.017678
#    645          CASC15-RPS10  0.015256
#    805         PLA2G6-ZBTB7A  0.015177
#    726         MYO7A-MIR378I  0.013721
#    181              PAM-FNTA  0.013618
#    707         ECHDC3-MIR940  0.012292
#    818            CASC10-MAF  0.011635
#    772         LILRA3-MIR940  0.011617
#    288            CD14-BECN1  0.011122
#    748             SUN1-JDP2  0.010352
#    79            UBE2M-SF3B2  0.009857
#    717            MYO7A-LEF1  0.009592
#    789          GOLGA8J-CREM  0.009497
#    799     LINC00471-MIR4420  0.009153
#    735             PAM-HOXB3  0.008791
#    757             RFNG-ATF6  0.008517
#    828  RP11-108L7.4-MIR644A  0.008260
#    287           CD14-COX6A1  0.008166
#    814         IGF2R-MIR4453  0.008113
#    771         LILRA3-MIR621  0.007429
#    808        ZNF502-MIR4453  0.006595
#    792         GOLGA8J-PRDM1  0.006438
#    450          CASC10-RPS10  0.006409
#    667          HDAC5-ZBTB7A  0.006398
#    803          PLA2G6-NR2F6  0.006365
#    225          SPICE1-RPS10  0.006291
#    706        ECHDC3-MIR3609  0.005832
#    768        LILRA3-MIR3936  0.005695
#    765          CD14-MIR4519  0.005057
#    670            CLIP4-MITF  0.004987
#    804         PLA2G6-POU2F2  0.004322
#    333            BCL2-BECN1  0.003814
#    391           PLA2G6-FNTA  0.003173
#    778           MTSS1-NR1I2  0.001763
#    301           LILRA3-FNTA  0.001071},
#   115: {'random_state': 115,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.8421052631578947,
#    'Precision': 0.6363636363636364,
#    'sensitivity': 0.7777777777777778,
#    'F1_score': 0.7000000000000001,
#    'specificity': 0.8620689655172413,
#    'balanced_acc': 0.8199233716475096,
#    'recall': 0.7777777777777778,
#    'precision_independent': 0.8108108108108109,
#    'sensitivity_independent': 0.47619047619047616,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.7086834733893557,
#    'ACC_independent': 0.7802197802197802,
#    'F1_score_independent': 0.6,
#    'recall_independent': 0.47619047619047616,
#    'features':                    Feature       IMP
#    764            CD14-ZNF689  0.181386
#    93            LILRB2-BECN1  0.060275
#    674              NPC2-CTCF  0.051867
#    421             IGF2R-FNTA  0.046435
#    777            MTSS1-CEBPA  0.038003
#    751             SUN1-NR2C2  0.037091
#    748              SUN1-JDP2  0.032929
#    333             BCL2-BECN1  0.030564
#    675             NPC2-GATA2  0.027983
#    836    CTD-3203P2.1-MIR553  0.026399
#    767         LILRA3-MIR4442  0.025456
#    137           GDF11-COX6A1  0.024275
#    788           C1QA-MIR4519  0.024198
#    91             LILRB2-FNTA  0.022584
#    672           CLIP4-MIR635  0.022563
#    832      CDK2AP2P2-MIR4292  0.021746
#    225           SPICE1-RPS10  0.021245
#    286              CD14-FNTA  0.021171
#    420            IGF2R-RPS10  0.019455
#    732           FGD4-MIR4519  0.018527
#    60             ACOT9-RPS10  0.016879
#    272            RFNG-COX6A1  0.015674
#    256              SUN1-FNTA  0.014978
#    687           ACOT9-MIR621  0.014072
#    49              NPC2-SF3B2  0.013587
#    846  RP11-355B11.2-MIR4519  0.013566
#    805          PLA2G6-ZBTB7A  0.013110
#    778            MTSS1-NR1I2  0.012939
#    181               PAM-FNTA  0.012760
#    717             MYO7A-LEF1  0.012536
#    726          MYO7A-MIR378I  0.012390
#    667           HDAC5-ZBTB7A  0.012336
#    452          CASC10-COX6A1  0.012049
#    18             HDAC5-BECN1  0.011426
#    706         ECHDC3-MIR3609  0.010926
#    166              FGD4-FNTA  0.010697
#    707          ECHDC3-MIR940  0.009785
#    422           IGF2R-COX6A1  0.007906
#    451            CASC10-FNTA  0.007812
#    92           LILRB2-COX6A1  0.006528
#    287            CD14-COX6A1  0.003889},
#   120: {'random_state': 120,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.8157894736842105,
#    'Precision': 0.6666666666666666,
#    'sensitivity': 0.4444444444444444,
#    'F1_score': 0.5333333333333333,
#    'specificity': 0.9310344827586207,
#    'balanced_acc': 0.6877394636015326,
#    'recall': 0.4444444444444444,
#    'precision_independent': 0.7380952380952381,
#    'sensitivity_independent': 0.49206349206349204,
#    'specificity_independent': 0.907563025210084,
#    'blanced_acc_independent': 0.699813258636788,
#    'ACC_independent': 0.7637362637362637,
#    'F1_score_independent': 0.5904761904761904,
#    'recall_independent': 0.49206349206349204,
#    'features':                  Feature       IMP
#    286            CD14-FNTA  0.152462
#    137         GDF11-COX6A1  0.063481
#    748            SUN1-JDP2  0.056169
#    48            NPC2-BECN1  0.054026
#    392        PLA2G6-COX6A1  0.044303
#    788         C1QA-MIR4519  0.044092
#    332          BCL2-COX6A1  0.039312
#    777          MTSS1-CEBPA  0.037436
#    674            NPC2-CTCF  0.035294
#    420          IGF2R-RPS10  0.028066
#    138          GDF11-BECN1  0.026484
#    789         GOLGA8J-CREM  0.025583
#    645         CASC15-RPS10  0.024931
#    181             PAM-FNTA  0.024627
#    345           C1QA-RPS10  0.021115
#    802          PLA2G6-KLF4  0.020959
#    836  CTD-3203P2.1-MIR553  0.019379
#    333           BCL2-BECN1  0.018872
#    792        GOLGA8J-PRDM1  0.018472
#    450         CASC10-RPS10  0.016290
#    421           IGF2R-FNTA  0.015546
#    422         IGF2R-COX6A1  0.015391
#    93          LILRB2-BECN1  0.014158
#    808       ZNF502-MIR4453  0.013962
#    734            PAM-FOXK1  0.012182
#    757            RFNG-ATF6  0.012108
#    707        ECHDC3-MIR940  0.012098
#    822      AC138623.1-LEF1  0.011786
#    823   AC138623.1-MIR4420  0.010649
#    771        LILRA3-MIR621  0.010581
#    672         CLIP4-MIR635  0.009622
#    799    LINC00471-MIR4420  0.009187
#    255           SUN1-RPS10  0.008901
#    837  RP11-83N9.5-MIR644A  0.008518
#    804        PLA2G6-POU2F2  0.008320
#    92         LILRB2-COX6A1  0.007272
#    91           LILRB2-FNTA  0.006335
#    834       EEF1GP2-MIR635  0.006137
#    767       LILRA3-MIR4442  0.005854
#    818           CASC10-MAF  0.005852
#    784            BCL2-TCF4  0.005547
#    661         CLASP1-CEBPD  0.005347
#    816         CASC10-EPAS1  0.004690
#    763             CD14-WT1  0.004304
#    660           CLASP1-AHR  0.003759
#    288           CD14-BECN1  0.000543},
#   125: {'random_state': 125,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.6666666666666666,
#    'sensitivity': 0.8888888888888888,
#    'F1_score': 0.761904761904762,
#    'specificity': 0.8620689655172413,
#    'balanced_acc': 0.8754789272030651,
#    'recall': 0.8888888888888888,
#    'precision_independent': 0.6666666666666666,
#    'sensitivity_independent': 0.5079365079365079,
#    'specificity_independent': 0.865546218487395,
#    'blanced_acc_independent': 0.6867413632119514,
#    'ACC_independent': 0.7417582417582418,
#    'F1_score_independent': 0.5765765765765767,
#    'recall_independent': 0.5079365079365079,
#    'features':            Feature       IMP
#    286      CD14-FNTA  0.113547
#    687   ACOT9-MIR621  0.056187
#    225   SPICE1-RPS10  0.044378
#    748      SUN1-JDP2  0.041521
#    288     CD14-BECN1  0.037986
#    ..             ...       ...
#    804  PLA2G6-POU2F2  0.002030
#    722     MYO7A-TAL1  0.000606
#    732   FGD4-MIR4519  0.000488
#    818     CASC10-MAF  0.000254
#    255     SUN1-RPS10  0.000057
#
#    [64 rows x 2 columns]},
#   130: {'random_state': 130,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.7894736842105263,
#    'Precision': 0.5555555555555556,
#    'sensitivity': 0.5555555555555556,
#    'F1_score': 0.5555555555555556,
#    'specificity': 0.8620689655172413,
#    'balanced_acc': 0.7088122605363985,
#    'recall': 0.5555555555555556,
#    'precision_independent': 0.8205128205128205,
#    'sensitivity_independent': 0.5079365079365079,
#    'specificity_independent': 0.9411764705882353,
#    'blanced_acc_independent': 0.7245564892623716,
#    'ACC_independent': 0.7912087912087912,
#    'F1_score_independent': 0.6274509803921569,
#    'recall_independent': 0.5079365079365079,
#    'features':                    Feature       IMP
# ...
#    738            PAM-ZNF680  0.018891
#    286             CD14-FNTA  0.018449
#    120          ECHDC3-RPS10  0.017793
#    840      SMC5-AS1-MIR4648  0.017765
#    777           MTSS1-CEBPA  0.017750
#    17           HDAC5-COX6A1  0.017656
#    79            UBE2M-SF3B2  0.017631
#    165            FGD4-RPS10  0.017447
#    107           DPF2-COX6A1  0.016560
#    725         MYO7A-ZSCAN31  0.016407
#    61             ACOT9-FNTA  0.015978
#    841   ZSCAN16-AS1-MIR4312  0.015908
#    797     LINC00471-MIR378I  0.015177
#    722            MYO7A-TAL1  0.013646
#    665            HDAC5-CUX1  0.013253
#    181              PAM-FNTA  0.013127
#    780            BCL2-FOXO1  0.013090
#    829  RP11-108L7.4-MIR3128  0.013053
#    688            UBE2M-ETS1  0.012951
#    788          C1QA-MIR4519  0.012924
#    663         CLASP1-POU2F2  0.012839
#    791          GOLGA8J-LEF1  0.011806
#    136            GDF11-FNTA  0.010995
#    451           CASC10-FNTA  0.010879
#    645          CASC15-RPS10  0.010384
#    423           IGF2R-BECN1  0.009913
#    754             SUN1-THRA  0.009747
#    683            ACOT9-NFYB  0.009584
#    837   RP11-83N9.5-MIR644A  0.009200
#    811          IGF2R-DNAJC1  0.008657
#    787          BCL2-MIR3648  0.008270
#    809         IGF2R-BHLHE41  0.007820
#    821    RP1-257A7.4-MIR621  0.006941
#    256             SUN1-FNTA  0.006260
#    726         MYO7A-MIR378I  0.005505},
#   160: {'random_state': 160,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.7631578947368421,
#    'Precision': 0.7777777777777778,
#    'sensitivity': 0.7368421052631579,
#    'F1_score': 0.7567567567567567,
#    'specificity': 0.7894736842105263,
#    'balanced_acc': 0.763157894736842,
#    'recall': 0.7368421052631579,
#    'precision_independent': 0.8640776699029126,
#    'sensitivity_independent': 0.8090909090909091,
#    'specificity_independent': 0.8055555555555556,
#    'blanced_acc_independent': 0.8073232323232323,
#    'ACC_independent': 0.8076923076923077,
#    'F1_score_independent': 0.8356807511737089,
#    'recall_independent': 0.8090909090909091,
#    'features':                 Feature       IMP
#    732        FGD4-MIR4519  0.096638
#    256           SUN1-FNTA  0.025639
#    166           FGD4-FNTA  0.022389
#    808      ZNF502-MIR4453  0.021698
#    819       CASC10-POU6F1  0.021106
#    ..                  ...       ...
#    792       GOLGA8J-PRDM1  0.001362
#    824  AC138623.1-MIR5194  0.001233
#    717          MYO7A-LEF1  0.001099
#    740        VENTX-MIR621  0.001068
#    738          PAM-ZNF680  0.000853
#
#    [115 rows x 2 columns]},
#   165: {'random_state': 165,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.8157894736842105,
#    'Precision': 0.8,
#    'sensitivity': 0.8421052631578947,
#    'F1_score': 0.8205128205128205,
#    'specificity': 0.7894736842105263,
#    'balanced_acc': 0.8157894736842105,
#    'recall': 0.8421052631578947,
#    'precision_independent': 0.8640776699029126,
#    'sensitivity_independent': 0.8090909090909091,
#    'specificity_independent': 0.8055555555555556,
#    'blanced_acc_independent': 0.8073232323232323,
#    'ACC_independent': 0.8076923076923077,
#    'F1_score_independent': 0.8356807511737089,
#    'recall_independent': 0.8090909090909091,
#    'features':                   Feature       IMP
#    732          FGD4-MIR4519  0.111147
#    136            GDF11-FNTA  0.054283
#    93           LILRB2-BECN1  0.052618
#    301           LILRA3-FNTA  0.052244
#    675            NPC2-GATA2  0.046627
#    50             NPC2-PSMB2  0.029395
#    120          ECHDC3-RPS10  0.025593
#    819         CASC10-POU6F1  0.023965
#    798     LINC00471-MIR4648  0.023653
#    836   CTD-3203P2.1-MIR553  0.023332
#    138           GDF11-BECN1  0.021559
#    333            BCL2-BECN1  0.021294
#    810            IGF2R-CUX1  0.021200
#    303          LILRA3-BECN1  0.019975
#    674             NPC2-CTCF  0.019039
#    107           DPF2-COX6A1  0.018327
#    797     LINC00471-MIR378I  0.018234
#    770        LILRA3-MIR3153  0.016904
#    243           NIPBL-BECN1  0.015942
#    286             CD14-FNTA  0.015311
#    316            MTSS1-FNTA  0.015271
#    710            GDF11-RBPJ  0.014656
#    839      SMC5-AS1-MIR378I  0.014474
#    688            UBE2M-ETS1  0.014455
#    799     LINC00471-MIR4420  0.013784
#    348            C1QA-BECN1  0.013060
#    777           MTSS1-CEBPA  0.012948
#    707         ECHDC3-MIR940  0.012393
#    332           BCL2-COX6A1  0.012047
#    79            UBE2M-SF3B2  0.011502
#    165            FGD4-RPS10  0.010493
#    834        EEF1GP2-MIR635  0.010383
#    840      SMC5-AS1-MIR4648  0.010210
#    754             SUN1-THRA  0.010174
#    49             NPC2-SF3B2  0.010103
#    683            ACOT9-NFYB  0.009911
#    722            MYO7A-TAL1  0.009892
#    791          GOLGA8J-LEF1  0.009600
#    630   RP11-355B11.2-RPS10  0.009483
#    829  RP11-108L7.4-MIR3128  0.009092
#    181              PAM-FNTA  0.009073
#    835       EEF1GP2-MIR3176  0.008819
#    665            HDAC5-CUX1  0.008775
#    422          IGF2R-COX6A1  0.008332
#    663         CLASP1-POU2F2  0.007950
#    788          C1QA-MIR4519  0.007783
#    828  RP11-108L7.4-MIR644A  0.007764
#    841   ZSCAN16-AS1-MIR4312  0.007679
#    740          VENTX-MIR621  0.007400
#    808        ZNF502-MIR4453  0.007325
#    776          MTSS1-BCL11A  0.006954
#    837   RP11-83N9.5-MIR644A  0.006561
#    645          CASC15-RPS10  0.006438
#    182            PAM-COX6A1  0.006317
#    709            GDF11-NFIA  0.006217
#    121           ECHDC3-FNTA  0.005913
#    809         IGF2R-BHLHE41  0.005546
#    717            MYO7A-LEF1  0.005438
#    698        LILRB2-MIR4519  0.005142},
#   170: {'random_state': 170,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.7368421052631579,
#    'Precision': 0.8,
#    'sensitivity': 0.631578947368421,
#    'F1_score': 0.7058823529411765,
#    'specificity': 0.8421052631578947,
#    'balanced_acc': 0.7368421052631579,
#    'recall': 0.631578947368421,
#    'precision_independent': 0.8365384615384616,
#    'sensitivity_independent': 0.7909090909090909,
#    'specificity_independent': 0.7638888888888888,
#    'blanced_acc_independent': 0.7773989898989899,
#    'ACC_independent': 0.7802197802197802,
#    'F1_score_independent': 0.8130841121495327,
#    'recall_independent': 0.7909090909090909,
#    'features':               Feature       IMP
#    732      FGD4-MIR4519  0.097720
#    811      IGF2R-DNAJC1  0.069965
#    819     CASC10-POU6F1  0.031332
#    303      LILRA3-BECN1  0.030026
#    839  SMC5-AS1-MIR378I  0.021809
#    ..                ...       ...
#    722        MYO7A-TAL1  0.000765
#    738        PAM-ZNF680  0.000379
#    182        PAM-COX6A1  0.000239
#    810        IGF2R-CUX1  0.000152
#    96        LILRB2-AUP1  0.000043
#
#    [101 rows x 2 columns]},
#   175: {'random_state': 175,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.7368421052631579,
#    'Precision': 0.8,
#    'sensitivity': 0.631578947368421,
#    'F1_score': 0.7058823529411765,
#    'specificity': 0.8421052631578947,
#    'balanced_acc': 0.7368421052631579,
#    'recall': 0.631578947368421,
#    'precision_independent': 0.8640776699029126,
#    'sensitivity_independent': 0.8090909090909091,
#    'specificity_independent': 0.8055555555555556,
#    'blanced_acc_independent': 0.8073232323232323,
#    'ACC_independent': 0.8076923076923077,
#    'F1_score_independent': 0.8356807511737089,
#    'recall_independent': 0.8090909090909091,
#    'features':                    Feature       IMP
#    675             NPC2-GATA2  0.125984
#    732           FGD4-MIR4519  0.083023
#    93            LILRB2-BECN1  0.055123
#    674              NPC2-CTCF  0.040777
#    763               CD14-WT1  0.040342
#    333             BCL2-BECN1  0.034674
#    819          CASC10-POU6F1  0.033472
#    781             BCL2-NFKB2  0.028786
#    788           C1QA-MIR4519  0.027843
#    316             MTSS1-FNTA  0.023973
#    424            IGF2R-SF3B2  0.022813
#    347            C1QA-COX6A1  0.020744
#    673             NPC2-ATF6B  0.020475
#    345             C1QA-RPS10  0.020426
#    707          ECHDC3-MIR940  0.019216
#    422           IGF2R-COX6A1  0.019139
#    695           LILRB2-RUNX1  0.018531
#    770         LILRA3-MIR3153  0.016757
#    332            BCL2-COX6A1  0.015943
#    107            DPF2-COX6A1  0.015780
#    166              FGD4-FNTA  0.014076
#    725          MYO7A-ZSCAN31  0.013868
#    181               PAM-FNTA  0.013403
#    391            PLA2G6-FNTA  0.013377
#    138            GDF11-BECN1  0.013036
#    782              BCL2-RELB  0.012318
#    726          MYO7A-MIR378I  0.012000
#    738             PAM-ZNF680  0.011980
#    710             GDF11-RBPJ  0.011924
#    18             HDAC5-BECN1  0.011299
#    829   RP11-108L7.4-MIR3128  0.011024
#    195            VENTX-RPS10  0.010925
#    451            CASC10-FNTA  0.010876
#    665             HDAC5-CUX1  0.010751
#    645           CASC15-RPS10  0.010084
#    79             UBE2M-SF3B2  0.010037
#    668             CLIP4-E2F1  0.009853
#    30             CLIP4-RPS10  0.009832
#    846  RP11-355B11.2-MIR4519  0.009467
#    136             GDF11-FNTA  0.008960
#    120           ECHDC3-RPS10  0.008953
#    17            HDAC5-COX6A1  0.007625
#    834         EEF1GP2-MIR635  0.007358
#    722             MYO7A-TAL1  0.007163
#    837    RP11-83N9.5-MIR644A  0.007060
#    348             C1QA-BECN1  0.006801
#    797      LINC00471-MIR378I  0.006489
#    828   RP11-108L7.4-MIR644A  0.006134
#    301            LILRA3-FNTA  0.006065
#    824     AC138623.1-MIR5194  0.005916
#    225           SPICE1-RPS10  0.005880
#    818             CASC10-MAF  0.005846
#    777            MTSS1-CEBPA  0.005795},
#   180: {'random_state': 180,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.868421052631579,
#    'Precision': 0.85,
#    'sensitivity': 0.8947368421052632,
#    'F1_score': 0.8717948717948718,
#    'specificity': 0.8421052631578947,
#    'balanced_acc': 0.868421052631579,
#    'recall': 0.8947368421052632,
#    'precision_independent': 0.8787878787878788,
#    'sensitivity_independent': 0.7909090909090909,
#    'specificity_independent': 0.8333333333333334,
#    'blanced_acc_independent': 0.8121212121212121,
#    'ACC_independent': 0.8076923076923077,
#    'F1_score_independent': 0.8325358851674641,
#    'recall_independent': 0.7909090909090909,
#    'features':                 Feature       IMP
#    732        FGD4-MIR4519  0.096678
#    673          NPC2-ATF6B  0.040926
#    303        LILRA3-BECN1  0.032458
#    333          BCL2-BECN1  0.031658
#    819       CASC10-POU6F1  0.026307
#    ..                  ...       ...
#    108          DPF2-BECN1  0.001484
#    792       GOLGA8J-PRDM1  0.001184
#    805       PLA2G6-ZBTB7A  0.000736
#    765        CD14-MIR4519  0.000703
#    824  AC138623.1-MIR5194  0.000216
#
#    [83 rows x 2 columns]},
#   185: {'random_state': 185,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100},
#    'Accuracy': 0.7368421052631579,
#    'Precision': 0.7368421052631579,
#    'sensitivity': 0.7368421052631579,
#    'F1_score': 0.7368421052631579,
#    'specificity': 0.7368421052631579,
#    'balanced_acc': 0.7368421052631579,
#    'recall': 0.7368421052631579,
#    'precision_independent': 0.8673469387755102,
#    'sensitivity_independent': 0.7727272727272727,
#    'specificity_independent': 0.8194444444444444,
#    'blanced_acc_independent': 0.7960858585858586,
#    'ACC_independent': 0.7912087912087912,
#    'F1_score_independent': 0.8173076923076923,
#    'recall_independent': 0.7727272727272727,
#    'features':                   Feature       IMP
#    732          FGD4-MIR4519  0.137268
#    782             BCL2-RELB  0.080682
#    819         CASC10-POU6F1  0.036373
#    695          LILRB2-RUNX1  0.035280
#    243           NIPBL-BECN1  0.031391
#    195           VENTX-RPS10  0.031051
#    303          LILRA3-BECN1  0.030248
#    795      LINC00471-MIR635  0.029522
#    301           LILRA3-FNTA  0.029488
#    333            BCL2-BECN1  0.026561
#    674             NPC2-CTCF  0.025394
#    49             NPC2-SF3B2  0.025163
#    738            PAM-ZNF680  0.023637
#    770        LILRA3-MIR3153  0.023305
#    345            C1QA-RPS10  0.022624
#    422          IGF2R-COX6A1  0.019538
#    707         ECHDC3-MIR940  0.018969
#    837   RP11-83N9.5-MIR644A  0.015755
#    777           MTSS1-CEBPA  0.015601
#    92          LILRB2-COX6A1  0.015234
#    818            CASC10-MAF  0.014459
#    316            MTSS1-FNTA  0.013901
#    300          LILRA3-RPS10  0.013373
#    61             ACOT9-FNTA  0.013288
#    226           SPICE1-FNTA  0.013054
#    17           HDAC5-COX6A1  0.012733
#    829  RP11-108L7.4-MIR3128  0.012713
#    834        EEF1GP2-MIR635  0.012678
#    421            IGF2R-FNTA  0.012146
#    138           GDF11-BECN1  0.011350
#    663         CLASP1-POU2F2  0.011279
#    120          ECHDC3-RPS10  0.011001
#    95           LILRB2-PSMB2  0.010878
#    797     LINC00471-MIR378I  0.010864
#    706        ECHDC3-MIR3609  0.010574
#    754             SUN1-THRA  0.010264
#    694         UBE2M-MIR3916  0.010166
#    93           LILRB2-BECN1  0.009647
#    709            GDF11-NFIA  0.009481
#    107           DPF2-COX6A1  0.009178
#    348            C1QA-BECN1  0.009171
#    726         MYO7A-MIR378I  0.009101
#    841   ZSCAN16-AS1-MIR4312  0.008626
#    665            HDAC5-CUX1  0.008460
#    181              PAM-FNTA  0.008234
#    788          C1QA-MIR4519  0.007957
#    79            UBE2M-SF3B2  0.007818
#    741         VENTX-MIR4519  0.007504
#    840      SMC5-AS1-MIR4648  0.007223
#    737             PAM-RUNX3  0.006813
#    784             BCL2-TCF4  0.006113
#    711           GDF11-TRPS1  0.005990
#    791          GOLGA8J-LEF1  0.000348
#    285            CD14-RPS10  0.000347
#    315           MTSS1-RPS10  0.000115
#    799     LINC00471-MIR4420  0.000067},
#   190: {'random_state': 190,
#    'best_params': {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 100},
#    'Accuracy': 0.7631578947368421,
#    'Precision': 0.7777777777777778,
#    'sensitivity': 0.7368421052631579,
#    'F1_score': 0.7567567567567567,
#    'specificity': 0.7894736842105263,
#    'balanced_acc': 0.763157894736842,
#    'recall': 0.7368421052631579,
#    'precision_independent': 0.84,
#    'sensitivity_independent': 0.7636363636363637,
#    'specificity_independent': 0.7777777777777778,
#    'blanced_acc_independent': 0.7707070707070707,
#    'ACC_independent': 0.7692307692307693,
#    'F1_score_independent': 0.8000000000000002,
#    'recall_independent': 0.7636363636363637,
#    'features':             Feature       IMP
#    675      NPC2-GATA2  0.098251
#    788    C1QA-MIR4519  0.077790
#    780      BCL2-FOXO1  0.032123
#    107     DPF2-COX6A1  0.030165
#    762      CD14-MEF2D  0.027308
#    ..              ...       ...
#    724    MYO7A-ZNF549  0.001640
#    769  LILRA3-MIR3609  0.001239
#    808  ZNF502-MIR4453  0.000786
#    137    GDF11-COX6A1  0.000265
#    79      UBE2M-SF3B2  0.000016
#
#    [104 rows x 2 columns]},
#   195: {'random_state': 195,
#    'best_params': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100},
#    'Accuracy': 0.7368421052631579,
#    'Precision': 0.7368421052631579,
#    'sensitivity': 0.7368421052631579,
#    'F1_score': 0.7368421052631579,
#    'specificity': 0.7368421052631579,
#    'balanced_acc': 0.7368421052631579,
#    'recall': 0.7368421052631579,
#    'precision_independent': 0.8365384615384616,
#    'sensitivity_independent': 0.7909090909090909,
#    'specificity_independent': 0.7638888888888888,
#    'blanced_acc_independent': 0.7773989898989899,
#    'ACC_independent': 0.7802197802197802,
#    'F1_score_independent': 0.8130841121495327,
#    'recall_independent': 0.7909090909090909,
#    'features':                  Feature       IMP
#    675           NPC2-GATA2  0.114688
#    732         FGD4-MIR4519  0.085012
#    788         C1QA-MIR4519  0.055625
#    791         GOLGA8J-LEF1  0.031809
#    762           CD14-MEF2D  0.029133
#    ..                   ...       ...
#    630  RP11-355B11.2-RPS10  0.001238
#    803         PLA2G6-NR2F6  0.001191
#    120         ECHDC3-RPS10  0.000607
#    804        PLA2G6-POU2F2  0.000378
#    91           LILRB2-FNTA  0.000290
#
#    [105 rows x 2 columns]}}}

# %%
Value_list = []
Type_list = []
Threshold_list = []
ACC_list = []
ACC_independent_test_list = []
F1_list = []
F1_independent_test_list = []

for Threshod in  result_with_threshod:
    for random_state in result_with_threshod[Threshod]:
        if "balanced_acc" in result_with_threshod[Threshod][random_state]:
            ACC_list.append(result_with_threshod[Threshod][random_state]['balanced_acc'])
        if "blanced_acc_independent" in result_with_threshod[Threshod][random_state]:
            ACC_independent_test_list.append(result_with_threshod[Threshod][random_state]['blanced_acc_independent'])
            
        if "F1_score" in result_with_threshod[Threshod][random_state]:
            F1_list.append(result_with_threshod[Threshod][random_state]['F1_score'])
        if "F1_score_independent" in result_with_threshod[Threshod][random_state]:
            F1_independent_test_list.append(result_with_threshod[Threshod][random_state]['F1_score_independent'])

        Threshold_list.append(Threshod)

# %%
import seaborn as sns
plt.figure(figsize = (3,3),dpi = 300)
acc_df=pd.DataFrame({"Threshod":Threshold_list+Threshold_list, 
                     "Balanced_ACC":ACC_list+ACC_independent_test_list, 
                     "dataset":['W1/2']*len(Threshold_list) +['W3/4']*len(Threshold_list)})

sns.boxplot(x="Threshod", y="Balanced_ACC",
            hue="dataset", palette=["grey", "red"],
            data=acc_df)
plt.ylim(0,1)
plt.title(Drug.split("(")[0])
plt.xticks(range(0,len(threshold_list_label)), threshold_list_label, rotation = 90)

for threshold in set(Threshold_list):
    print("threshold:" + str(threshold))
    x = acc_df.loc[acc_df['Threshod'] == threshold]
    print("W1/2:Balanced_ACC")
    print(np.median(x.loc[x['dataset'] =='W1/2']['Balanced_ACC'].values))
    print("W3/4:Balanced_ACC")
    print(np.median(x.loc[x['dataset'] =='W3/4']['Balanced_ACC'].values))
# Out:
# threshold:0.0190925713799281
# W1/2:Balanced_ACC
# 0.8266283524904214
# W3/4:Balanced_ACC
# 0.699813258636788
# threshold:1.45261900330956
# W1/2:Balanced_ACC
# 0.763157894736842
# W3/4:Balanced_ACC
# 0.7863636363636364

# %%
import seaborn as sns
plt.figure(figsize = (3,3),dpi = 300)
acc_df=pd.DataFrame({"Threshod":Threshold_list+Threshold_list, 
                     "F1_score":F1_list+F1_independent_test_list, 
                     "dataset":['W1/2']*len(Threshold_list) +['W3/4']*len(Threshold_list)})

sns.boxplot(x="Threshod", y="F1_score",
            hue="dataset", palette=["grey", "red"],
            data=acc_df)
plt.ylim(0,1)
plt.title(Drug.split("(")[0])
plt.xticks(range(0,len(threshold_list_label)), threshold_list_label, rotation = 90)

for threshold in set(Threshold_list):
    print("threshold:" + str(threshold))
    x = acc_df.loc[acc_df['Threshod'] == threshold]
    print("W1/2:F1")
    print(np.median(x.loc[x['dataset'] =='W1/2']['F1_score'].values))
    print("W3/4:F1")
    print(np.median(x.loc[x['dataset'] =='W3/4']['F1_score'].values))
# Out:
# threshold:0.0190925713799281
# W1/2:F1
# 0.7320574162679425
# W3/4:F1
# 0.5898809523809523
# threshold:1.45261900330956
# W1/2:F1
# 0.7533783783783784
# W3/4:F1
# 0.821621502436443

# %%
feature_drug_df = pd.DataFrame()

sele_threshold = q50
for drug in [Drug]:
    test = result_with_threshod
    cur = test[sele_threshold]
    feature_df = pd.DataFrame()
    for random in cur:
        if cur[random]['Accuracy'] > 0.7 :
            feature_df_cur = cur[random]['features']
            feature_df_cur["IMP_"+str(random)]  = feature_df_cur['IMP']
            feature_df_cur.index = feature_df_cur['Feature']
            feature_df = pd.concat([feature_df, feature_df_cur["IMP_"+str(random)] ], axis =1)
    feature_df_sum = feature_df.sum(axis = 1)/feature_df.shape[1]
    result = pd.DataFrame({"features":feature_df_sum.index, 
                           "IMP":feature_df_sum.values, 
                           "Drug":[drug]*len(feature_df_sum.index)})
    
    feature_drug_df = pd.concat([feature_drug_df, result])

# %%
# Plot top important features 
feature_IMP =pd.DataFrame()
Threshold = q50
for random_state in result_with_threshod[Threshold]:
    if result_with_threshod[Threshold][random_state]['balanced_acc'] > 0.7:
        features = result_with_threshod[Threshold][random_state]['features']['Feature'].values
        IMP = result_with_threshod[Threshold][random_state]['features']['IMP'].values
        cur_df = pd.DataFrame({"IMP" + str(random_state): IMP})
        cur_df.index = features
        feature_IMP = pd.concat([feature_IMP,cur_df ],axis =1)
print(feature_IMP.shape)
IMP_sum = feature_IMP.transpose().sum()/feature_IMP.transpose().shape[0]
x_feature = pd.DataFrame({"Feature":IMP_sum.index, "IMP":IMP_sum.values})
x_feature_sorted = x_feature.sort_values(by = ["IMP"], ascending = False).head(20)

plt.figure(figsize = (4,3),dpi = 300)
plt.title("Feature_importance: " + Drug.split("(")[0])
plt.bar(np.arange(0,x_feature_sorted.shape[0], 1), x_feature_sorted['IMP'], width=0.8,  color = 'grey',
        bottom=None,  align='center')
#plt.ylabel("correlation coeffient")
plt.xticks(np.arange(0,x_feature_sorted.shape[0], 1),x_feature_sorted['Feature'] , rotation = 90, fontsize =8)
# Out:
# (203, 34)
# ([<matplotlib.axis.XTick at 0x141e72fb0>,
#   <matplotlib.axis.XTick at 0x141e71ff0>,
#   <matplotlib.axis.XTick at 0x105601660>,
#   <matplotlib.axis.XTick at 0x14283d060>,
#   <matplotlib.axis.XTick at 0x14283d7b0>,
#   <matplotlib.axis.XTick at 0x14283d510>,
#   <matplotlib.axis.XTick at 0x14283e0b0>,
#   <matplotlib.axis.XTick at 0x14283e800>,
#   <matplotlib.axis.XTick at 0x14283ef50>,
#   <matplotlib.axis.XTick at 0x14283f6a0>,
#   <matplotlib.axis.XTick at 0x14283fdf0>,
#   <matplotlib.axis.XTick at 0x14283fe50>,
#   <matplotlib.axis.XTick at 0x14283ece0>,
#   <matplotlib.axis.XTick at 0x142854460>,
#   <matplotlib.axis.XTick at 0x142854b20>,
#   <matplotlib.axis.XTick at 0x142855270>,
#   <matplotlib.axis.XTick at 0x1428559c0>,
#   <matplotlib.axis.XTick at 0x142856110>,
#   <matplotlib.axis.XTick at 0x14283ecb0>,
#   <matplotlib.axis.XTick at 0x142855c90>],
#  [Text(0, 0, 'FGD4-MIR4519'),
#   Text(1, 0, 'NPC2-GATA2'),
#   Text(2, 0, 'CASC10-POU6F1'),
#   Text(3, 0, 'BCL2-BECN1'),
#   Text(4, 0, 'IGF2R-DNAJC1'),
#   Text(5, 0, 'MTSS1-FNTA'),
#   Text(6, 0, 'C1QA-MIR4519'),
#   Text(7, 0, 'IGF2R-COX6A1'),
#   Text(8, 0, 'NPC2-CTCF'),
#   Text(9, 0, 'BCL2-FOXO1'),
#   Text(10, 0, 'LILRA3-BECN1'),
#   Text(11, 0, 'GDF11-FNTA'),
#   Text(12, 0, 'LILRB2-BECN1'),
#   Text(13, 0, 'GOLGA8J-LEF1'),
#   Text(14, 0, 'BCL2-NFKB2'),
#   Text(15, 0, 'BCL2-RELB'),
#   Text(16, 0, 'ECHDC3-MIR940'),
#   Text(17, 0, 'NPC2-SF3B2'),
#   Text(18, 0, 'PAM-ZNF680'),
#   Text(19, 0, 'C1QA-RPS10')])

# %%
result_with_threshod.keys()
# Out:
# dict_keys([0.0190925713799281, 1.45261900330956])
